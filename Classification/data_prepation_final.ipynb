# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import scipy
import statsmodels.formula.api as smf
import statsmodels.api as sm

from sklearn import model_selection, preprocessing, feature_selection, ensemble, linear_model, metrics, decomposition
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

from datetime import datetime
sub_info=pd.read_csv("subjectinfo.csv")

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub1.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub1.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=30
df["Gender"]="M"
df["heigth"]=177
df["weigth"]= 94

df_sub1=df.copy()

df_sub1
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time        ax       ay        az       temp       EDA
# 0 1900-01-01 00:00:00  0.760015 -0.86999 -0.100004  30.100043  0.083039
# 1 1900-01-01 00:00:01  0.750005 -0.86999 -0.110031  30.100043  0.081028
# 2 1900-01-01 00:00:02  0.750005 -0.86999 -0.110031  30.100043  0.081028
#          Elapsed time        ax       ay        az       temp       EDA  \
# 0 1900-01-01 00:00:00  0.760015 -0.86999 -0.100004  30.100043  0.083039
# 1 1900-01-01 00:00:01  0.750005 -0.86999 -0.110031  30.100043  0.081028
# 2 1900-01-01 00:00:02  0.750005 -0.86999 -0.110031  30.100043  0.081028
#
#         SpO2         hr class
# ...

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub2.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub2.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=28
df["Gender"]="M"
df["heigth"]=172
df["weigth"]= 68

df_sub2=df.copy()

df_sub2
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time        ax        ay        az       temp       EDA
# 0 1900-01-01 00:00:00  0.969971 -0.670058 -0.070045  28.700095  0.818044
# 1 1900-01-01 00:00:01  0.969971 -0.670058 -0.070045  28.900095  0.818044
# 2 1900-01-01 00:00:02  0.979983 -0.670058 -0.070045  28.900095  0.816017
#          Elapsed time        ax        ay        az       temp       EDA  \
# 0 1900-01-01 00:00:00  0.969971 -0.670058 -0.070045  28.700095  0.818044
# 1 1900-01-01 00:00:01  0.969971 -0.670058 -0.070045  28.900095  0.818044
# 2 1900-01-01 00:00:02  0.979983 -0.670058 -0.070045  28.900095  0.816017
#
#         SpO2         hr class
# ...

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub5.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub5.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=30
df["Gender"]="M"
df["heigth"]=182
df["weigth"]= 82

df_sub5=df.copy()

df_sub5
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#              Elapsed time        ax        ay        az       temp       EDA
# 0 1900-01-01 00:00:00.125 -0.799968 -0.230007  0.019996  27.900070  0.239014
# 1 1900-01-01 00:00:01.125 -0.809972 -0.220033  0.000000  28.100027  0.239014
# 2 1900-01-01 00:00:02.125 -0.799968 -0.230007  0.000000  27.900070  0.238017
#              Elapsed time        ax        ay        az       temp       EDA  \
# 0 1900-01-01 00:00:00.125 -0.799968 -0.230007  0.019996  27.900070  0.239014
# 1 1900-01-01 00:00:01.125 -0.809972 -0.220033  0.000000  28.100027  0.239014
# 2 1900-01-01 00:00:02.125 -0.799968 -0.230007  0.000000  27.900070  0.238017
#
# ...

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub6.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub6.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=30
df["Gender"]="F"
df["heigth"]=167
df["weigth"]= 58

df_sub6=df.copy()

df_sub6
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time        ax        ay        az       temp       EDA
# 0 1900-01-01 00:00:00  0.440007 -1.200022  0.130049  24.900037  0.071001
# 1 1900-01-01 00:00:01  0.859972 -0.410045  0.569993  24.900037  0.069001
# 2 1900-01-01 00:00:02 -0.199962 -1.010056 -0.099975  24.900037  0.069001
#          Elapsed time        ax        ay        az       temp       EDA  \
# 0 1900-01-01 00:00:00  0.440007 -1.200022  0.130049  24.900037  0.071001
# 1 1900-01-01 00:00:01  0.859972 -0.410045  0.569993  24.900037  0.069001
# 2 1900-01-01 00:00:02 -0.199962 -1.010056 -0.099975  24.900037  0.069001
#
#    SpO2         hr class
# ...

# %%
 def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub7.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub7.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=33
df["Gender"]="F"
df["heigth"]=157
df["weigth"]= 90

df_sub7=df.copy()

df_sub7
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time       ax        ay        az       temp       EDA
# 0 1900-01-01 00:00:00  0.55997 -0.979996 -0.020023  26.000049  0.465036
# 1 1900-01-01 00:00:01  0.57997 -0.969967 -0.030035  26.000049  0.465036
# 2 1900-01-01 00:00:02  0.59997 -0.959973 -0.040009  26.000049  0.465036
#          Elapsed time       ax        ay        az       temp       EDA  SpO2  \
# 0 1900-01-01 00:00:00  0.55997 -0.979996 -0.020023  26.000049  0.465036  95.0
# 1 1900-01-01 00:00:01  0.57997 -0.969967 -0.030035  26.000049  0.465036  95.0
# 2 1900-01-01 00:00:02  0.59997 -0.959973 -0.040009  26.000049  0.465036  95.0
#
#      hr class
# ...

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub9.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub9.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=25
df["Gender"]="M"
df["heigth"]=177
df["weigth"]= 68

df_sub9=df.copy()

df_sub9
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time        ax        ay        az       temp       EDA
# 0 1900-01-01 00:00:00  0.919989 -0.720000 -0.070028  26.400014  1.103041
# 1 1900-01-01 00:00:01  1.019948 -0.650009 -0.130006  26.400014  1.107000
# 2 1900-01-01 00:00:02  0.799995 -0.840000 -0.130006  26.400014  1.107000
#          Elapsed time        ax        ay        az       temp       EDA  \
# 0 1900-01-01 00:00:00  0.919989 -0.720000 -0.070028  26.400014  1.103041
# 1 1900-01-01 00:00:01  1.019948 -0.650009 -0.130006  26.400014  1.107000
# 2 1900-01-01 00:00:02  0.799995 -0.840000 -0.130006  26.400014  1.107000
#
#         SpO2         hr class
# ...

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub10.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub10.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=23
df["Gender"]="M"
df["heigth"]=180
df["weigth"]= 64

df_sub10=df.copy()

df_sub10
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time        ax        ay        az       temp       EDA
# 0 1900-01-01 00:00:00  0.449968 -1.009969 -0.040004  27.000064  3.251014
# 1 1900-01-01 00:00:01  0.449968 -1.009969 -0.040004  27.000064  3.256052
# 2 1900-01-01 00:00:02  0.410031 -1.019987 -0.030003  27.000064  3.256052
#          Elapsed time        ax        ay        az       temp       EDA  \
# 0 1900-01-01 00:00:00  0.449968 -1.009969 -0.040004  27.000064  3.251014
# 1 1900-01-01 00:00:01  0.449968 -1.009969 -0.040004  27.000064  3.256052
# 2 1900-01-01 00:00:02  0.410031 -1.019987 -0.030003  27.000064  3.256052
#
#         SpO2         hr class
# ...

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub12.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub12.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=32
df["Gender"]="F"
df["heigth"]=162
df["weigth"]= 53

df_sub12=df.copy()

df_sub12
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time        ax        ay        az       temp      EDA
# 0 1900-01-01 00:00:00  0.429954 -1.019992 -0.080040  27.000069  0.42506
# 1 1900-01-01 00:00:01  0.409975 -1.019992 -0.070041  27.000069  0.42506
# 2 1900-01-01 00:00:02  0.419988 -1.019992 -0.070041  27.000069  0.42506
#          Elapsed time        ax        ay        az       temp      EDA  \
# 0 1900-01-01 00:00:00  0.429954 -1.019992 -0.080040  27.000069  0.42506
# 1 1900-01-01 00:00:01  0.409975 -1.019992 -0.070041  27.000069  0.42506
# 2 1900-01-01 00:00:02  0.419988 -1.019992 -0.070041  27.000069  0.42506
#
#         SpO2         hr class
# ...

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub13.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub13.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=29
df["Gender"]="F"
df["heigth"]=167
df["weigth"]= 64

df_sub13=df.copy()

df_sub13
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time        ax        ay        az       temp       EDA
# 0 1900-01-01 00:00:00  1.149969 -0.490061 -0.110024  27.400052  0.445045
# 1 1900-01-01 00:00:01  1.089981 -0.470056 -0.210030  27.400052  0.448008
# 2 1900-01-01 00:00:02  1.089981 -0.470056 -0.210030  27.200067  0.448008
#          Elapsed time        ax        ay        az       temp       EDA  \
# 0 1900-01-01 00:00:00  1.149969 -0.490061 -0.110024  27.400052  0.445045
# 1 1900-01-01 00:00:01  1.089981 -0.470056 -0.210030  27.400052  0.448008
# 2 1900-01-01 00:00:02  1.089981 -0.470056 -0.210030  27.200067  0.448008
#
#         SpO2         hr class
# ...

# %%
def parser(t):
    return datetime.strptime(t,"\'%M:%S.%f\'")

df_1 = pd.read_csv("s1sub14.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_2 = pd.read_csv("s2sub14.csv",parse_dates=['Elapsed time'] , date_parser = parser)
df_1['class']="class"
df_2['class']='class'

f=1
s_df=5*60*f
i=0
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_1['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_1['class'].iloc[i*s_df:]='Rest'
f=8
s_df=5*60*f
i=0
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Physical'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Cognitive'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Rest'
i=i+1;
df_2['class'].iloc[i*s_df:(i+1)*s_df]='Emotional'
i=i+1;
df_2['class'].iloc[i*s_df:]='Rest'
l=int(len(df_2)/f)
df_sam= df_2.iloc[:l,:6]
df_sam.dtypes

for i in range(l):
    df_sam.iloc[i,0:4]=df_2.iloc[i*8,:5]
 
display(df_sam.head(3))
df = pd.concat([ df_sam,df_1.iloc[:,1:]], axis=1)
df=df.iloc[:min(len(df_1),len(df_sam)),:]
display(df.head(3))
df.dtypes


df['age']=19
df["Gender"]="F"
df["heigth"]=160
df["weigth"]= 50

df_sub14=df.copy()

df_sub14
# Out:
# C:\Users\VK\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#          Elapsed time        ax   ay        az       temp       EDA
# 0 1900-01-01 00:00:00  0.689979 -0.9  0.069985  28.900015  0.709017
# 1 1900-01-01 00:00:01  0.679979 -0.9  0.069985  28.900015  0.709017
# 2 1900-01-01 00:00:02  0.689979 -0.9  0.069985  28.900015  0.706035
#          Elapsed time        ax   ay        az       temp       EDA  \
# 0 1900-01-01 00:00:00  0.689979 -0.9  0.069985  28.900015  0.709017
# 1 1900-01-01 00:00:01  0.679979 -0.9  0.069985  28.900015  0.709017
# 2 1900-01-01 00:00:02  0.689979 -0.9  0.069985  28.900015  0.706035
#
#         SpO2    hr class
# 0  93.999863  67.0  Rest
# 1  93.999863  66.0  Rest
# ...

# %%
df_final=pd.concat([df_sub1,df_sub2,df_sub5,df_sub6,df_sub7,df_sub9,df_sub10,df_sub12,df_sub13,df_sub14])

# %%
df_final
# Out:
#             Elapsed time        ax        ay        az       temp       EDA  \
# 0    1900-01-01 00:00:00  0.760015 -0.869990 -0.100004  30.100043  0.083039
# 1    1900-01-01 00:00:01  0.750005 -0.869990 -0.110031  30.100043  0.081028
# 2    1900-01-01 00:00:02  0.750005 -0.869990 -0.110031  30.100043  0.081028
# 3    1900-01-01 00:00:03  0.750005 -0.879993 -0.100004  30.100043  0.079018
# 4    1900-01-01 00:00:04  0.760015 -0.859987 -0.100004  30.100043  0.081028
# ...                  ...       ...       ...       ...        ...       ...
# 2273 1900-01-01 00:37:53 -0.279991 -0.900000  0.210000  31.799991  0.380018
# 2274 1900-01-01 00:37:54 -0.279991 -0.900000  0.210000  31.799991  0.379038
# 2275 1900-01-01 00:37:55 -0.279991 -0.900000  0.210000  31.799991  0.381040
# 2276 1900-01-01 00:37:56 -0.279991 -0.900000  0.210000  31.999948  0.379038
# 2277 1900-01-01 00:37:57 -0.279991 -0.900000  0.210000  31.799991  0.381040
#
# ...

# %%
df_final=df_final.drop(["Elapsed time"], axis=1)

# %%
df_final.reset_index(drop=True,inplace=False)
# Out:
#              ax        ay        az       temp       EDA       SpO2  \
# 0      0.760015 -0.869990 -0.100004  30.100043  0.083039  96.999969
# 1      0.750005 -0.869990 -0.110031  30.100043  0.081028  96.999969
# 2      0.750005 -0.869990 -0.110031  30.100043  0.081028  96.999969
# 3      0.750005 -0.879993 -0.100004  30.100043  0.079018  96.999969
# 4      0.760015 -0.859987 -0.100004  30.100043  0.081028  96.999969
# ...         ...       ...       ...        ...       ...        ...
# 22801 -0.279991 -0.900000  0.210000  31.799991  0.380018  93.999863
# 22802 -0.279991 -0.900000  0.210000  31.799991  0.379038  93.999863
# 22803 -0.279991 -0.900000  0.210000  31.799991  0.381040  93.999863
# 22804 -0.279991 -0.900000  0.210000  31.999948  0.379038  93.999863
# 22805 -0.279991 -0.900000  0.210000  31.799991  0.381040  93.999863
#
#               hr class  age Gender  heigth  weigth
# 0      89.000763  Rest   30      M     177      94
# ...

# %%
df_final
# Out:
#             ax        ay        az       temp       EDA       SpO2         hr  \
# 0     0.760015 -0.869990 -0.100004  30.100043  0.083039  96.999969  89.000763
# 1     0.750005 -0.869990 -0.110031  30.100043  0.081028  96.999969  88.000137
# 2     0.750005 -0.869990 -0.110031  30.100043  0.081028  96.999969  87.000443
# 3     0.750005 -0.879993 -0.100004  30.100043  0.079018  96.999969  87.000443
# 4     0.760015 -0.859987 -0.100004  30.100043  0.081028  96.999969  87.000443
# ...        ...       ...       ...        ...       ...        ...        ...
# 2273 -0.279991 -0.900000  0.210000  31.799991  0.380018  93.999863  55.000000
# 2274 -0.279991 -0.900000  0.210000  31.799991  0.379038  93.999863  55.000000
# 2275 -0.279991 -0.900000  0.210000  31.799991  0.381040  93.999863  56.000000
# 2276 -0.279991 -0.900000  0.210000  31.999948  0.379038  93.999863  56.000000
# 2277 -0.279991 -0.900000  0.210000  31.799991  0.381040  93.999863  56.000000
#
# ...

# %%
df_final.to_csv("Final_Data_set.csv")
