# %% [markdown]
# #### Armia modules import

# %%
# !pip install --upgrade statsmodels
# !pip install pmdarima
from pmdarima.arima import auto_arima
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMA
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (0.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.19.5)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (1.8.4)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.13.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.0.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)

# %% [markdown]
# # modules import

# %%
from matplotlib import pyplot as plt
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
from pandas import datetime
from matplotlib import pyplot

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from statsmodels.tools.eval_measures import rmse
import math

# %%
plt.style.use('classic')
# %matplotlib inline

# %% [markdown]
# # data input

# %%
def parser(t):
    return datetime.strptime(t,"\'[%H:%M:%S %d/%m/%Y]\'")


df = pd.read_csv("samples_spo2.csv",header=0,index_col=0,parse_dates=['Time and date'] , date_parser = parser,squeeze=True) 
df.head(5)
# Out:
# Time and date
# 1995-05-11 11:00:24    94
# 1995-05-11 11:00:25    94
# 1995-05-11 11:00:26    94
# 1995-05-11 11:00:27    94
# 1995-05-11 11:00:28    94
# Name: SpO2, dtype: int64

# %%
plt.figure(figsize=(7,4))
df.plot()
plt.ylim([0,130])
plt.xlabel('Time',size=15)
plt.ylabel('SpO2',size=15)
plt.grid()
plt.show()

# %% [markdown]
# #### data visulisation

# %% [markdown]
# Box-plot: to understand the distribution of values by time interval. Outliers can be detected i.e, irrelavent values (like 0 in the above graph) so that these can be replaced with other relavent values.

# %%
from pandas import Grouper, DataFrame,concat
# one_day = df['1995-05-11']

groups = df.groupby(Grouper(freq='H'))

# for x in groups:
#   print(x)

hours = concat([DataFrame(x[1].values) for x in groups], axis=1)
hourse = DataFrame(hours)
hours.columns = range(1,28)

plt.figure(figsize=(20,10))
hours.boxplot()
plt.show()

# %%
groups = df.groupby(Grouper(freq='D'))
dates = concat([DataFrame(x[1].values) for x in groups], axis=1)
dates = DataFrame(dates)
dates.columns = range(1,3)

plt.figure(figsize=(7,5))
dates.boxplot()
plt.show()

# %% [markdown]
# The PULSE is stable on the second day when compared to the day-1

# %%
groups = df.groupby(Grouper(freq='4H'))
hours = concat([DataFrame(x[1].values) for x in groups], axis=1)
hours = DataFrame(hours)
hours.columns = range(1,9)

hours.plot(subplots=True,legend=False)
plt.show()

# plt.figure(figsize=(20,10))
# hours.boxplot()
# plt.show()

# %% [markdown]
# To compare the relation b/w the previous and present values plotting lag plot with lag=1. Since it is one day data... we cannot compare b/w days.
# Try to get more than one day data and compare within days to observe any trends.

# %%
from pandas.plotting import lag_plot, autocorrelation_plot
lag_plot(df) #lag=1

# %% [markdown]
# Seasonal trends - explains the periodic upps and downs. in a on day data, the peak and low pulse is at what point of time.

# %%
autocorrelation_plot(df)
plt.show()

# %% [markdown]
# # Resamling Dataset

# %%
df1=df

for i in range(1,len(df1)):
  if df1[i]==0:
    df1[i]=df1[i-1]

from pandas.plotting import lag_plot, autocorrelation_plot
plt.figure(figsize=[7,4])
lag_plot(df,lag=1) #lag=1
plt.xlabel('y(t)',size=15)
plt.ylabel('y(t+1)',size=15)
# plt.xlim([55,105])
# plt.ylim([55,105])
plt.grid()
plt.show()

# %%
df1 = df1.resample('10S').mean()
df1
plt.figure(figsize=(20,6))
df1.plot()
plt.show()

# %% [markdown]
# #### data visualisation after resampling

# %%
# one_day = df['1995-05-11']
groups = df1.groupby(Grouper(freq='H'))

# for x in groups:
#   print(x)

hours = concat([DataFrame(x[1].values) for x in groups], axis=1)
hourse = DataFrame(hours)
hours.columns = range(1,28)

plt.figure(figsize=(20,10))
hours.boxplot()
plt.show()

# %%
# one_day = df['1995-05-11']
groups = df1.groupby(Grouper(freq='D'))
dates = concat([DataFrame(x[1].values) for x in groups], axis=1)
dates = DataFrame(dates)
dates.columns = range(1,3)

plt.figure(figsize=(20,10))
dates.boxplot()
plt.show()

# %% [markdown]
# #### correlation & adf tests

# %%
from pandas.plotting import lag_plot, autocorrelation_plot
lag_plot(df1) #lag=1

# %%
# correlation
values = DataFrame(df1.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)


#=> good correlation
# Out:
#           t-1       t+1
# t-1  1.000000  0.860204
# t+1  0.860204  1.000000

# %%
autocorrelation_plot(df1)

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_acf(df1)
plt.show()
plot_pacf(df1)
plt.show()

# %%
groups = df1.groupby(Grouper(freq='4H'))
hours = concat([DataFrame(x[1].values) for x in groups], axis=1)
hourse = DataFrame(hours)
hours.columns = range(1,9)

# %% [markdown]
# Agumented Dickey Fuller Test - to test whether the data is stationary or not. This test is used to check whether the series has unit root or not? if it exists, the model is stationary.

# %% [markdown]
# What is stationary data - mean, variance and autocorrelation sturcture do not change/depend with time
# If the data donot have trend/seasonality, it is stationary.
# trends (long-term increasing or decreasing movement)
# seasonality (consistent periodic structure)

# %% [markdown]
# How to make data stationary - if there is clear trend,sesonality then model the components, remove from observations and train models on residuals

# %%
X=df1.values
X1,X2 = X[:round(len(X)/2)],X[round(len(X)/2):]
mean1,mean2 = X1.mean(),X2.mean()
var1,var2 = X1.var(),X2.var()
print(mean1,mean2)
print(var1,var2)
# Out:
# 67.15912967417451 64.33186092280779
# 54.731708142598556 33.85348083611347

# %% [markdown]
# Mean doesn't vary much... variance?

# %%
df11, df12 = df1[:round(len(X)/2)],df1[round(len(X)/2):] 
df11.hist(bins=50)
df12.hist(bins=50)
plt.show()

# %%
df1.hist(bins=100)
plt.show()

# %% [markdown]
# Not a gaussian => mean and variance are less meaningful => can be non-stationary

# %%
X_log = np.log(X)
plt.hist(X_log,bins=50)
plt.show()
plt.plot(X_log)
plt.show()

# %% [markdown]
# Not an exponential sesonality

# %%
#ADF #kpss #PP
from statsmodels.tsa.stattools import adfuller,kpss

X=df1.values
result_adf = adfuller(df1)
print(result_adf)

result_kpss = kpss(df1)
print(result_kpss)
# Out:
# (-5.656922383771096, 9.573784079647399e-07, 33, 9332, {'1%': -3.431050932240579, '5%': -2.861849767913357, '10%': -2.5669348843771203}, 47994.46214351107)
# (4.208890465992514, 0.01, 38, {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# ADF - to determine given series follows a trend or not.
# The test statistic is -5. The more negative the statistic is, the more we reject null hypothesis. The statistic value < 5%,1% values => rejecting null hypothesis. Also p-value is close to zero.
# Hence stationary...!!

# %% [markdown]
# Similarly kpss test(null-hypo:stationary series). if p-val<0.05 => non-stationary
# here p-val>0.05 => stationary

# %%
# ADF test
import pmdarima
adf_test = pmdarima.arima.ADFTest(alpha=0.05)
adf_test.should_diff(df1)
# Out:
# (0.01, False)

# %% [markdown]
# #### persistance model

# %% [markdown]
# Basic model:
# Persistance model, it uses t-1 value to predict the t+1 value.
# baseline algo

# %%
vals = pd.DataFrame(df1.values)
print(vals.head())
dataframe = pd.concat([vals.shift(1),vals],axis=1)
print(dataframe.head())
X=dataframe.values
print(X)
train,test = X[:int(len(X)*0.8)],X[int(len(X)*0.8):]
# 10*6*3 = last 3mins
train_X,train_y = train[:,0],train[:,1]
test_X,test_y = test[:,0],test[:,1]

def model_persistence(x):
  return x

predictions = list()
for x in test_X:
  yhat = model_persistence(x)
  predictions.append(yhat)
err_pm = rmse(test_y, predictions)
print('RMSE is {}'.format(err_pm))

plt.figure(figsize=(20,5))
plt.plot(test_y)
plt.plot(predictions)
plt.show()
# Out:
#            0
# 0  69.666667
# 1  69.000000
# 2  69.200000
# 3  70.000000
# 4  70.000000
#            0          0
# 0        NaN  69.666667
# 1  69.666667  69.000000
# 2  69.000000  69.200000
# 3  69.200000  70.000000
# 4  70.000000  70.000000
# [[        nan 69.66666667]
#  [69.66666667 69.        ]
#  [69.         69.2       ]
#  ...
#  [59.4        61.2       ]
#  [61.2        63.        ]
#  [63.         62.        ]]
# RMSE is 1.8352758951993555

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_acf(dfn)
plt.show()
plot_pacf(dfn)
plt.show()

# %% [markdown]
# # Train - Test split

# %%
len(df1.values)
# Out:
# 9366

# %%
# dfn =  df1[:4000]

X = df1.values
train,test = X[:int(len(X)*0.8)],X[int(len(X)*0.8):]

plt.figure(figsize=(20,8))
plt.plot(train)
plt.plot([None for i in train]+[x for x in test])
plt.show()
#train data & test data

# %%
train_data,test_data = X[:int(len(X)*0.8)],X[int(len(X)*0.8):]

# %% [markdown]
# ##### splitting - not required cell

# %%
from sklearn.model_selection import TimeSeriesSplit
splits = TimeSeriesSplit(n_splits = 3)

plt.figure(1)
index=1
for train_index, test_index in splits.split(X):
	train = X[train_index]
	test = X[test_index]
	print('Observations: %d' % (len(train) + len(test)))
	print('Training : %d' % (len(train)))
	print('Testing : %d' % (len(test)))
	plt.subplot(310 + index)
	plt.plot(train)
	plt.plot([None for i in train] + [x for x in test])
	index += 1
plt.show()
# Out:
# Observations: 4684
# Training : 2343
# Testing : 2341
# Observations: 7025
# Training : 4684
# Testing : 2341
# Observations: 9366
# Training : 7025
# Testing : 2341

# %% [markdown]
# #### AR

# %% [markdown]
# Auto regression model - linear reg using lagged values

# %% [markdown]
# Basic:

# %%
lags = 60
model = AutoReg(train,lags=lags)
model_fit = model.fit()

predictions = model_fit.predict(start=len(train),end=len(X)-1)

rmse_ar = rmse(test,predictions)
print(rmse_ar)

mae = mean_absolute_error(test,predictions)
print(mae)

plt.figure(figsize=(20,5))
plt.plot(test)
plt.plot(predictions)
plt.show()
# Out:
# 1.1806624843577624
# 0.9056843906884524

# %% [markdown]
# ##### With window validation

# %%
lags = 60
model = AutoReg(train,lags=lags)
model_fit = model.fit()
coef = model_fit.params

window = lags #1
history = train[len(train)-window :]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	yhat = coef[0]
	for d in range(window):
		yhat += coef[d+1] * lag[window-d-1]
	obs = test[t]
	predictions.append(yhat)
	history.append(obs)

rmse_ar = rmse(test,predictions)
print(rmse_ar)

plt.figure(figsize=(20,5))
plt.plot(test)
plt.plot(predictions)
plt.show()
# Out:
# 2.9218110868499876

# %% [markdown]
# #### ARMIA

# %% [markdown]
# Moving Average: takes the average of raw observations.
# centered MA: Smoothing method to remove seasonality and trneds (or) to remove the irregularities in the data
# trailing MA: avg of present and past values to predict next value. Used for forecasting. To do this, the data has to be stationary.(no trend/seasonality).

# %%
model = ARIMA(train,order=(0,0,1))
model_fit=model.fit()
predictions = model_fit.predict(start=len(train),end=len(X)-1)

rmse_ar = rmse(test,predictions)
print(rmse_ar)

mae = mean_absolute_error(test,predictions)
print(mae)

# %%
# X = df1.values
# train,test = X[:int(len(X)*0.8)],X[int(len(X)*0.8):]

window = 1
history = train[len(train)-window :]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
  length = len(history)
  yhat = np.mean([history[i] for i in range(length-window,length)])
  obs = test[t]
  # obs = yhat
  predictions.append(yhat)
  history.append(obs)

rmse_ar = rmse(test,predictions)
print(rmse_ar)

# plt.figure(figsize=(20,5))
# plt.plot(test)
# plt.plot(predictions)
# plt.show()
# Out:
# 5.151517875321126

# %% [markdown]
# Auto ARIMA

# %%
arima_model = auto_arima(train, start_p=1, d=0, start_q=1, max_p=7, max_q=3, 
                         seasonal=False, error_action='warn', trace=True, random_state=20, n_fits=10)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=41078.129, Time=0.58 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=83998.355, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=74120.704, Time=0.87 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=41040.326, Time=2.42 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=39778.126, Time=4.45 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.57 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=39735.790, Time=5.83 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=inf, Time=0.66 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=39733.549, Time=6.97 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=inf, Time=0.87 sec
#  ARIMA(6,0,1)(0,0,0)[0]             : AIC=39732.843, Time=9.53 sec
#  ARIMA(6,0,0)(0,0,0)[0]             : AIC=inf, Time=1.04 sec
#  ARIMA(7,0,1)(0,0,0)[0]             : AIC=39733.733, Time=10.67 sec
#  ARIMA(6,0,2)(0,0,0)[0]             : AIC=inf, Time=10.24 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=39739.038, Time=6.11 sec
#  ARIMA(7,0,0)(0,0,0)[0]             : AIC=inf, Time=1.35 sec
#  ARIMA(7,0,2)(0,0,0)[0]             : AIC=inf, Time=17.34 sec
#  ARIMA(6,0,1)(0,0,0)[0] intercept   : AIC=39936.589, Time=21.12 sec
#
# Best model:  ARIMA(6,0,1)(0,0,0)[0]
# Total fit time: 101.181 seconds

# %%
arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 7492
# Model:               SARIMAX(5, 1, 1)   Log Likelihood              -19852.840
# Date:                Sat, 08 May 2021   AIC                          39719.679
# Time:                        03:08:03   BIC                          39768.129
# Sample:                             0   HQIC                         39736.318
#                                - 7492
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7739      0.006    132.172      0.000       0.762       0.785
# ar.L2         -0.2370      0.007    -34.885      0.000      -0.250      -0.224
# ar.L3          0.1051      0.009     11.339      0.000       0.087       0.123
# ar.L4         -0.0384      0.010     -3.945      0.000      -0.058      -0.019
# ar.L5          0.0206      0.009      2.331      0.020       0.003       0.038
# ma.L1         -0.9536      0.004   -241.727      0.000      -0.961      -0.946
# sigma2        11.7331      0.051    229.391      0.000      11.633      11.833
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            267456.07
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.64   Skew:                             2.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                        31.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model = ARIMA(train,order=(0,0,0))
model_fit=model.fit()
predictions = model_fit.predict(start=len(train),end=len(X)-1)

rmse_ar = rmse(test,predictions)
print(rmse_ar)
# Out:
# 5.619864602977976

# %%
model = ARIMA(train,order=(1,1,2))
model_fit=model.fit()
dir_predictions = model_fit.predict(start=len(train),end=len(X)-1)

rmse_ar = rmse(test,predictions)
print(rmse_ar)
# Out:
# 5.619864602977976

# %%
train_data,test_data = X[:int(len(X)*0.8)],X[int(len(X)*0.8):]

# %%
model_arima = ARIMA(train,order=(6,1,1))
model_fit_arima=model_arima.fit()
dir_predictions = model_fit_arima.predict(start=len(train),end=len(X)-1)

rmse_arima = rmse(test,dir_predictions)
print(rmse_arima)

plt.figure(figsize=(20,8))
plt.plot(train_data)
plt.plot([None for i in train_data]+[x for x in test_data])
plt.plot([None for i in train_data]+[x for x in dir_predictions])
plt.show()
# Out:
# 66.03054124885698

# %%
model_arima = ARIMA(train,order=(6,0,1))
model_fit_arima=model_arima.fit()
dir_predictions = model_fit_arima.predict(start=len(train),end=len(X)-1)

rmse_arima = rmse(test,dir_predictions)
print(rmse_arima)

mae = mean_absolute_error(test,predictions)
print(mae)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-123-a0134d92e0d5> in <module>()
# ----> 1 model_arima = ARIMA(train,order=(6,0,1))
#       2 model_fit_arima=model_arima.fit()
#       3 dir_predictions = model_fit_arima.predict(start=len(train),end=len(X)-1)
#       4
#       5 rmse_arima = rmse(test,dir_predictions)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
plt.figure(figsize=(20,8))
plt.plot(train_data)
plt.plot([None for i in train_data]+[x for x in test_data])
plt.plot([None for i in train_data]+[x for x in dir_predictions])
plt.show()

# %% [markdown]
# lags = 5/10  ddiff=0 (since stationary) window=1

# %%
train_data,test_data = X[:int(len(X)*0.8)],X[int(len(X)*0.8):]

# %%
history = [x for x in train_data]
predictions = list()

lags=1
diff=0
window=1

for t in range(len(test_data)):
  print(t,end=" ")
  model=ARIMA(history,order=(lags,diff,window))
  model_fit = model.fit()
  output = model_fit.forecast()
  yhat = output[0]
  predictions.append(yhat)
  true_obs = test_data[t]
  history.append(true_obs)

print("\n")
MSE_error = mean_squared_error(test_data, predictions)
print('RMSE is {}'.format(math.sqrt(MSE_error)))



# o/p = 1.82
# Out:
# 1718 1719 1720 1721 1722 1723 1724 1725 1726 1727 1728 1729 1730 1731 1732 1733 1734 1735 1736 1737 1738 1739 1740 1741 1742 1743 1744 1745 1746 1747 1748 1749 1750 1751 1752 1753 1754 1755 1756 1757 1758 1759 1760 1761 1762 1763 1764 1765 1766 1767 1768 1769 1770 1771 1772 1773 1774 1775 1776 1777 1778 1779 1780 1781 1782 1783 1784 1785 1786 1787 1788 1789 1790 1791 1792 1793 1794 1795 1796 1797 1798 1799 1800 1801 1802 1803 1804 1805 1806 1807 1808 1809 1810 1811 1812 1813 1814 1815 1816 1817 1818 1819 1820 1821 1822 1823 1824 1825 1826 1827 1828 1829 1830 1831 1832 1833 1834 1835 1836 1837 1838 1839 1840 1841 1842 1843 1844 1845 1846 1847 1848 1849 1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862 1863 1864 1865 1866 1867 1868 1869 1870 1871 1872 1873
#
# RMSE is 1.8196403649420774

# %%
mae = mean_absolute_error(test_data,predictions)
print(mae)
# Out:
# 0.9967602806422002

# %%
# model_fit.plot_predict(1,10000)
# xt=model_fit.forecast(steps=200)

plt.figure(figsize=(20,8))
plt.plot(train_data)
plt.plot([None for i in train_data]+[x for x in test_data])
plt.plot([None for i in train_data]+[x for x in dir_predictions])
plt.plot([None for i in train_data]+[x for x in predictions])

plt.legend(["Training data", "Testing data","Arima predicted data","Arima predicted data with validation" ])
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(train_data)
plt.plot([None for i in train_data]+[x for x in test_data])
# plt.plot([None for i in train_data]+[x for x in dir_predictions])
plt.plot([None for i in train_data]+[x for x in predictions])

plt.legend(["Training data", "Testing data","Arima predicted data" ])
plt.show()

# %% [markdown]
# ### useful ARIMA

# %%
lags = 60
model = AutoReg(train,lags=lags)
model_fit = model.fit()

AR_predictions = model_fit.predict(start=len(train),end=len(X)-1)

rmse_ar = rmse(test,AR_predictions)
print(rmse_ar)

mae = mean_absolute_error(test,AR_predictions)
print(mae)

plt.figure(figsize=(20,5))
plt.plot(test)
plt.plot(AR_predictions)
plt.legend(['AR test data','AR predicted data'])
plt.show()
# Out:
# 4.458883373741747
# 3.820535344893763

# %%
import statsmodels.tsa.arima.model as stats
model_arima = stats.ARIMA(train,order=(6,0,2))
model_fit_arima=model_arima.fit()
arima_predictions = model_fit_arima.predict(start=len(train),end=len(X)-1)

rmse_arima = rmse(test,arima_predictions)
print(rmse_arima)

mae = mean_absolute_error(test,arima_predictions)
print(mae)
# Out:
# 4.4030623165189
# 3.7589365402920953

# %%
plt.figure(figsize=(20,5))
plt.plot(test)
plt.plot(arima_predictions)
plt.legend(['ARIMA test data','ARIMA predicted data'])
plt.show()

# %%
xi = df2.loc[int(len(X)*0.8):, 'Time and date']
yi = dataset_test.values

plt.figure(figsize=[7,4])
# plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dataset_test.values, label = 'Real Pulse rate',lw=2)
# plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],AR_predictions, label = 'AR predicted',lw=2)
# plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],arima_predictions, label = 'ARIMA predicted',lw=2)

plt.plot( xi[350:700],yi[350:700], label = 'Real Pulse rate',lw=1)
plt.plot(xi[350:700], AR_predictions[350:700],label = 'AR predicted',lw=1)
plt.plot(xi[350:700], arima_predictions[350:700],label = 'ARIMA predicted',lw=1)
plt.legend(loc='lower right')
plt.grid()



plt.xticks(rotation =45)

plt.xlabel('Time',size=15)
plt.ylabel('Pulse',fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9faf39cd09f2> in <module>()
#       1 xi = df2.loc[int(len(X)*0.8):, 'Time and date']
# ----> 2 yi = dataset_test.values
#       3
#       4 plt.figure(figsize=[7,4])
#       5 # plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dataset_test.values, label = 'Real Pulse rate',lw=2)
#
# NameError: name 'dataset_test' is not defined

# %% [markdown]
# # modules for models

# %%
train_data,test_data = X[:int(len(X)*0.8)],X[int(len(X)*0.8):]

# %%
import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Bidirectional

from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
df2 = df1.reset_index()
df2.head()
# Out:
#         Time and date  SpO2
# 0 1995-05-11 11:00:20  94.0
# 1 1995-05-11 11:00:30  94.0
# 2 1995-05-11 11:00:40  94.0
# 3 1995-05-11 11:00:50  94.0
# 4 1995-05-11 11:01:00  94.0

# %%
training_set, test_set = df2.iloc[:int(len(X)*0.8),1:2], df2.iloc[int(len(X)*0.8):,1:2]

sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

X_train = []
y_train = []
for i in range(60,int(len(X)*0.8) ):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
    
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
dataset_train = df2.iloc[: int(len(X)*0.8), 1:2]
dataset_test = df2.iloc[int(len(X)*0.8) :, 1:2]

dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
y_test = []
for i in range(60, len(X)-int(len(X)*0.8)+60):
    X_test.append(inputs[i-60:i, 0])
    y_test.append(inputs[i,0])

X_test = np.array(X_test)
y_test = np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (1874, 60, 1)

# %%
train = df.iloc[: int(len(X)*0.8)]
test = df.iloc[int(len(X)*0.8) :]
train.values
# Out:
# array([94, 94, 94, ..., 94, 94, 94])

# %%
# def transform_dataset(X, y, time_steps=1):
#     Xs, ys = [], []
#     for i in range(len(X) - time_steps):
#         v = X.iloc[i:(i + time_steps)].values
#         Xs.append(v)
#         ys.append(y.iloc[i + time_steps])
#     return np.array(Xs), np.array(ys)

# time_steps = 7

# X_train, y_train = transform_dataset(train, train, time_steps)
# X_test, y_test = transform_dataset(test, test, time_steps)

# %% [markdown]
# #### lstm

# %%
model = Sequential()

model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))

model.add(Dense(units = 1))


model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['mse'])
his_model = model.fit(X_train, y_train, epochs =100, batch_size = 64, validation_data=(X_test,y_test),shuffle=False)

# %%
lstm_predicted = model.predict(X_test)
lstm_predicted = sc.inverse_transform(lstm_predicted)



err_LSTM = rmse(dataset_test.values, lstm_predicted)
print('RMSE is {}'.format( err_LSTM))

MSE_error = mean_squared_error(dataset_test.values, lstm_predicted)
print('MSE is {}'.format(MSE_error))

mae = mean_absolute_error(test_data,lstm_predicted)
print(mae)
# Out:
# RMSE is [0.37931412]
# MSE is 0.14387919798253337
# 0.22948908525953426

# %%
# plt.figure(figsize=(20,8))
# plt.plot(train_data)
# plt.plot([None for i in train_data]+[x for x in test_data])
# plt.plot([None for i in train_data]+[x for x in lstm_predicted])
# plt.plot([None for i in train_data]+[x for x in predictions])

# plt.legend(["Training data", "Testing data","lstm_predicted","Arima predicted data" ])
# plt.show()

# %%
# plt.figure(figsize=(20,8))
# plt.plot(test_data)
# plt.plot(lstm_predicted)
# plt.plot(predictions)

# plt.legend(["Testing data","lstm_predicted","Arima predicted data" ])
# plt.show()

# %% [markdown]
# ## GRU

# %%
from keras.optimizers import *

model_gru = Sequential()
# Input layer
model_gru.add(GRU (units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model_gru.add(Dropout(0.2)) 
# Hidden layer
model_gru.add(GRU(units = 50)) 
model_gru.add(Dropout(0.2))
model_gru.add(Dense(units = 1))
# optimizer = Adam(lr=1e-3)
model_gru.compile(optimizer = 'adam',loss='mean_squared_error', metrics=['accuracy'])
model_gru.fit(X_train, y_train, epochs=100, batch_size=64, shuffle=False)

# %%
 
# serialize model to JSON
model_json = model_gru.to_json()
with open("model_spo2.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model_gru.save_weights("model_spo2.h5")
print("Saved model to disk")
model_gru.save('model_spo2.pkl')
# Out:
# Saved model to disk
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses, gru_cell_1_layer_call_fn, gru_cell_1_layer_call_and_return_conditional_losses, gru_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_spo2.pkl/assets
# INFO:tensorflow:Assets written to: model_spo2.pkl/assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x7fb842f03210> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x7fb842cc6c50> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# import pickle

# filename = 'modelHR.sav'
# pickle.dump(model_gru, open(filename, 'wb'))

# pkl_filename = "modelHR.pkl"
# with open(pkl_filename, 'wb') as file:
#     pickle.dump(model_gru, file)

# %%
dataset_train = df2.iloc[:int(len(X)*0.8), 1:2]
dataset_test = df2.iloc[int(len(X)*0.8):, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, len(X)-int(len(X)*0.8)+60):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (1874, 60, 1)

# %%
gru_predicted = model_gru.predict(X_test)
gru_predicted = sc.inverse_transform(gru_predicted)

# %%
err_GRU = rmse(dataset_test.values, gru_predicted)
print('RMSE is {}'.format( err_GRU))

# MSE_error = mean_squared_error(dataset_test.values, gru_predicted)
# print('MSE is {}'.format(MSE_error))

mae = mean_absolute_error(test_data,gru_predicted)
print(mae)
# Out:
# RMSE is [0.28152891]
# 0.1661823922737092

# %%
# import datetime
# cnt=7492
# e = '%Y-%m-%d %H:%M:%S'

# for i in xi:
#   # d = datetime.datetime.strptime(i, e)
#   i = datetime.datetime.strftime(i, '%H:%M:%S')
#   xi[cnt] = i
#   cnt+=1

# %%
# import datetime
# cnt=7492
# e = '%Y-%m-%d %H:%M:%S'

# for i in xi:
#   # d = datetime.datetime.strptime(i, e)
#   i = datetime.datetime.strftime(i, '%H:%M:%S')
#   xi[cnt] = i
#   cnt+=1

# %%
xi = list(range(150))
yi = dataset_test.values

plt.figure(figsize=[7,4])
plt.plot( xi[-150:],yi[-150:], label = 'Real SpO2',lw=1.5)
# plt.plot(xi[-150:], lstm_predicted[-150:],label = 'LSTM predicted',lw=1.5)
plt.plot(xi[-150:], gru_predicted[-150:],label = 'GRU predicted',lw=1.5)
# plt.plot(xi[-150:], AR_predictions[-150:],label = 'AR predicted',lw=1.5)
# plt.plot(xi[-150:], arima_predictions[-150:],label = 'ARIMA predicted',lw=1.5)
plt.legend(loc='upper right')
plt.grid()



# plt.xticks(rotation =45)

# plt.xlabel('Time',size=15)
plt.ylim([93.5,97])
plt.xlim([0,150])
plt.ylabel('SpO2',fontsize=15)
plt.xlabel('Time Stamp',fontsize=15)
plt.show()

# %%
xi = df2.loc[int(len(X)*0.8):, 'Time and date']
yi = dataset_test.values

plt.figure(figsize=[7,4])
plt.plot( xi[350:700],yi[350:700], label = 'Real Pulse rate',lw=1)
# plt.plot(xi[350:700], lstm_predicted[350:700],label = 'LSTM predicted',lw=1)
plt.plot(xi[350:700], gru_predicted[350:700],label = 'GRU predicted',lw=1)

plt.legend(loc='lower right')
plt.grid()



plt.xticks(rotation =45)

plt.xlabel('Time',size=15)
plt.ylabel('Pulse',fontsize=15)
plt.show()

# %%
xi = df2.loc[int(len(X)*0.8):, 'Time and date']
yi = dataset_test.values

plt.figure(figsize=[7,4])
plt.plot( xi[350:700],yi[350:700], label = 'Real Pulse rate',lw=1)
plt.plot(xi[350:700], lstm_predicted[350:700],label = 'LSTM predicted',lw=1)
plt.plot(xi[350:700], gru_predicted[350:700],label = 'GRU predicted',lw=1)
plt.plot(xi[350:700], AR_predictions[350:700],label = 'AR predicted',lw=1)
plt.plot(xi[350:700], arima_predictions[350:700],label = 'ARIMA predicted',lw=1)

plt.legend(loc='upper left')
plt.grid()



plt.xticks(rotation =45)

plt.xlabel('Time',size=15)
plt.ylabel('Pulse',fontsize=15)
plt.show()

# %%
plt.style.use('classic')
# %matplotlib inline

plt.figure(figsize=[7,4])
xi = list(range(int(len(X)*0.2)))
# xi = list(range(200))
# xi = df2.loc[int(len(X)*0.8):, 'Time and date']
yi = dataset_test.values
plt.plot( xi[:200],yi[:200], label = 'Real Pulse rate',lw=1.5)
plt.plot(xi[:200], gru_predicted[:200],label = 'GRU predicted',lw=1.5)
plt.legend(loc='upper left')
plt.grid()

# plt.title('Pulse')
# plt.xlabel('Time')
plt.ylabel('Pulse',fontsize=15)
plt.show()

# %%
plt.style.use('classic')
# %matplotlib inline

plt.figure(figsize=[7,4])
# xi = list(range(int(len(X)*0.2)))
xi = list(range(200))
# xi = df2.loc[int(len(X)*0.8):, 'Time and date']
yi = dataset_test.values
plt.plot( xi,yi[400:600] , label = 'Real Pulse rate',lw=2)
plt.plot(xi, gru_predicted[400:600],label = 'GRU predicted',lw=2)
plt.legend(loc='upper left')
plt.grid()

# plt.title('Pulse')
# plt.xlabel('Time')
plt.ylabel('Pulse')
plt.show()

# %%
# Visualising the results
plt.figure(figsize=[15,5])

plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dataset_test.values, label = 'Real Pulse rate',lw=2)
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],AR_predictions, label = 'AR predicted',lw=2)
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],arima_predictions, label = 'ARIMA predicted',lw=2)
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],lstm_predicted, label = 'LSTM predicted',lw=2)
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],gru_predicted,label = 'GRU predicted',lw=2)
plt.legend(loc='upper left')
plt.grid()

plt.title('Pulse')
plt.xlabel('Time')
plt.ylabel('Pulse')
plt.show()

# %% [markdown]
# #### output visualisation

# %%
# Visualising the results
plt.figure(figsize=[20,8])
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dataset_test.values, label = 'Real heart rate')
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],predictions, label = 'ARIMA predicted')
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],lstm_predicted, label = 'LSTM predicted')
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],gru_predicted,label = 'GRU predicted')
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dir_predictions, label = 'AR predicted')


plt.title('Heart rate')
plt.xlabel('Time')
plt.ylabel('Rate')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-30013791c3e7> in <module>()
#       3 plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dataset_test.values, label = 'Real heart rate')
#       4 plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],predictions, label = 'ARIMA predicted')
# ----> 5 plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],lstm_predicted, label = 'LSTM predicted')
#       6 plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],gru_predicted,label = 'GRU predicted')
#       7 plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dir_predictions, label = 'AR predicted')
#
# NameError: name 'lstm_predicted' is not defined

# %%
# Visualising the results
plt.figure(figsize=[20,8])
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dataset_test.values, label = 'Real heart rate',lw=2)
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],predictions, label = 'ARIMA predicted',lw=2)
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],lstm_predicted, label = 'LSTM predicted',lw=2)
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],gru_predicted,label = 'GRU predicted',lw=2)
plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dir_predictions, label = 'AR predicted',lw=2)

plt.title('Heart rate')
plt.xlabel('Time')
plt.ylabel('Rate')
plt.legend()
plt.show()

# %%
# Visualising the results
plt.figure(figsize=[20,8])
plt.plot(df2.loc[:int(len(X)*0.8)-1, 'Time and date'],dataset_train.values, label = 'Train data',lw=2.5)
# plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dataset_test.values, label = 'Real heart rate')
plt.plot(df2.loc[int(len(X)*0.8)-1:, 'Time and date'],[None for i in dataset_train]+[x for x in predictions], label = 'ARIMA predicted',lw=2.5)
plt.plot(df2.loc[int(len(X)*0.8)-1:, 'Time and date'],[None for i in dataset_train]+[x for x in lstm_predicted], label = 'LSTM predicted',lw=2.5)
plt.plot(df2.loc[int(len(X)*0.8)-1:, 'Time and date'],[None for i in dataset_train]+[x for x in gru_predicted],label = 'GRU predicted',lw=2.5)


plt.title('Heart rate')
plt.xlabel('Time')
plt.ylabel('Rate')
plt.legend()
plt.show()

# %%
# Visualising the results
plt.figure(figsize=[20,8])
plt.plot(df2.loc[int(len(X)*0.8/2)+1:int(len(X)*0.8)-1, 'Time and date'],dataset_train[int(len(X)*0.8/2):int(len(X)*0.8)-1].values, label = 'Train data',lw=2)
# plt.plot(df2.loc[int(len(X)*0.8):, 'Time and date'],dataset_test.values, label = 'Real heart rate')
plt.plot(df2.loc[int(len(X)*0.8)-1:, 'Time and date'],[None for i in dataset_train]+[x for x in predictions], label = 'ARIMA predicted',lw=2)
plt.plot(df2.loc[int(len(X)*0.8)-1:, 'Time and date'],[None for i in dataset_train]+[x for x in lstm_predicted], label = 'LSTM predicted',lw=2)
plt.plot(df2.loc[int(len(X)*0.8)-1:, 'Time and date'],[None for i in dataset_train]+[x for x in gru_predicted],label = 'GRU predicted',lw=2)
# plt.plot(df2.loc[int(len(X)*0.8)-1:, 'Time and date'],[None for i in dataset_train]+[x for x in dir_predictions],label = 'AR predicted',lw=2)


plt.title('Heart rate')
plt.xlabel('Time')
plt.ylabel('Rate')
plt.legend()
plt.show()

# %% [markdown]
# The fast and powerful methods that we rely on in machine learning, such as using train-test splits and k-fold cross validation, do not work in the case of time series data. This is because they ignore the temporal components inherent in the problem

# %%
plt.figure(figsize=(20,8))
plt.plot(train_data)
plt.plot([None for i in train_data]+[x for x in test_data])
plt.plot([None for i in train_data]+[x for x in lstm_predicted])
plt.plot([None for i in train_data]+[x for x in predictions])

plt.legend(["Training data", "Testing data","lstm_predicted","Arima predicted data" ])
plt.show()
